# %% [markdown]
# # pile range
# 214 - 216

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('classic')

# %%
N_group = 81
T = 10
T2 = 1
Left_edge = 214
Right_edge = 216

# %%
def data_load(path,N_group):
    f = open(path)
    lines = f.read()
    f.close()
    N_group = N_group
    lines1 = lines.split("\n",(1000*T+1)*N_group-1)
    data_list =[]
    for element in lines1:
        temp = element.split(' ',1)
        temp0 = temp[1]
        temp1 = temp0.strip()
        data_list.append(float(temp1))
    data = np.array(data_list)
    return data

# %% [markdown]
# # with_a_plie

# %% [markdown]
# ### u_disp_result_with_pile_210_230.txt

# %%
# 'u_disp_210_230_total41_with_a_plie.txt'
u_disp_210_230_total41_with_a_plie1 = data_load('u_disp_result_with_pile_210_230.txt',N_group)
u_disp_210_230_total41_with_a_plie2 = u_disp_210_230_total41_with_a_plie1.reshape(N_group,1000*T+1)
# 1200*41
u_disp_210_230_total41_with_a_plie3 = np.transpose(u_disp_210_230_total41_with_a_plie2)
# delete time 0
u_disp_210_230_total41_with_a_plie = u_disp_210_230_total41_with_a_plie3[1:int(1000*T2+1),:]
# test
plt.plot(u_disp_210_230_total41_with_a_plie[:,1])

# %% [markdown]
# # Without a pile

# %% [markdown]
# ### u_disp_result_without_pile_210_230_200N.txt

# %%
# 'u_disp_210_230_total41_without_a_plie.txt'
# N_group = 81
u_disp_210_230_total41_without_a_plie1 = data_load('u_disp_result_without_pile_210_230.txt',N_group)
u_disp_210_230_total41_without_a_plie2 = u_disp_210_230_total41_without_a_plie1.reshape(N_group,1000*T+1)
# 1200*41
u_disp_210_230_total41_without_a_plie3 = np.transpose(u_disp_210_230_total41_without_a_plie2)
# delete time 0
u_disp_210_230_total41_without_a_plie = u_disp_210_230_total41_without_a_plie3[1:int(1000*T2+1),:]
# test
plt.plot(u_disp_210_230_total41_without_a_plie[:,1])

# %% [markdown]
# # Comparison graph point by poit from 210 to 230

# %%
# u_disp_210_230_total41_with_a_plie vs u_disp_210_230_total41_without_a_plie
# for i in range(u_disp_210_230_total41_with_a_plie.shape[1]):
#     plt.title("u"+str(210+(i)*0.5))
#     plt.plot(u_disp_210_230_total41_with_a_plie[:,i],c = 'r',label = 'with a file')
#     plt.plot(u_disp_210_230_total41_without_a_plie[:,i],c = 'y',label = 'with no file')
#     plt.legend()
#     plt.show()

# %% [markdown]
# ## Maximum Amplitude

# %%
# Maximum Amplitude
# u_disp_210_230_total41_without_a_plie
app4 = []# postive max Amplitude
app4_1 = [] # negative max Amplitude
app4_3 = []# maximum abs Amplitude
app4_2 = [] # postive - negative
for i in range(u_disp_210_230_total41_without_a_plie.shape[1]):
    AA =  (u_disp_210_230_total41_without_a_plie[:,i])
    app4.append(AA.max()) # postive max Amplitude
    app4_1.append(AA.min()) # negative max Amplitude
    abs_AA = abs(AA)
    app4_3.append(abs_AA.max())# maximum abs Amplitude
app4_2 = np.array(app4) - np.array(app4_1) # postive - negative

# u_disp_210_230_total41_with_a_plie
app5 = [] # postive max Amplitude
app5_1 = []# negative max Amplitude
app5_3 = []# maximum abs Amplitude
app5_2 = [] # postive - negative

for i in range(u_disp_210_230_total41_with_a_plie.shape[1]):
    AA = (u_disp_210_230_total41_with_a_plie[:,i])
    app5.append(AA.max())# postive
    app5_1.append(AA.min())# negative
    abs_AA = abs(AA)
    app5_3.append(abs_AA.max())# maximum abs Amplitude
app5_2 = np.array(app5) -np.array(app5_1)# postive - negative

# %%
# postive max Amplitude
plt.figure(figsize=(20, 10))
plt.title("Postive Max Amplitude")
plt.plot(app4,c = 'y',label = "with no pile")# no pile
plt.plot(app5,c = 'r',label = "with a pile")# plie
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, app4[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,app4[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# # negative max Amplitude
plt.figure(figsize=(20, 10))
plt.title("negative Max Amplitude")
plt.plot(np.abs(app4_1),c = 'y',label = "with no pile")# no pile
plt.plot(np.abs(app5_1),c = 'r',label = "with a pile")# plie
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, np.abs(app4_1)[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,np.abs(app4_1)[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# # postive - negative
plt.figure(figsize=(20, 10))
plt.title("(postive - negative) Amplitude difference")
plt.plot(np.abs(app4_2),c = 'y',label = "with no pile")# no pile
plt.plot(np.abs(app5_2),c = 'r',label = "with a pile")# plie
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, np.abs(app4_2)[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,np.abs(app4_2)[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# # maximum abs Amplitude
plt.figure(figsize=(20, 10))
plt.title("Max abs Amplitude difference")
plt.plot(np.abs(app4_3),c = 'y',label = "with no pile")# no pile
plt.plot(np.abs(app5_3),c = 'r',label = "with a pile")# plie
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, np.abs(app4_3)[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,np.abs(app4_3)[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %% [markdown]
# ## Difference

# %%
# postive max Amplitude
plt.figure(figsize=(20, 10))
plt.title("Postive Max Amplitude difference")
diff = abs(np.array(app4) - np.array(app5))
plt.plot(diff)
plt.vlines((Left_edge-210)/0.5, 0, diff[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,diff[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# negative max Amplitude
plt.figure(figsize=(20, 10))
plt.title("negative Max Amplitude difference")
diff = abs(np.array(app4_1) - np.array(app5_1))

plt.plot(diff)
plt.vlines((Left_edge-210)/0.5, 0, diff[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,diff[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# # postive - negative
plt.figure(figsize=(20, 10))
plt.title("(postive - negative) Max Amplitude difference")
diff = abs(np.array(app4_2) - np.array(app5_2))
plt.plot(diff)
plt.vlines((Left_edge-210)/0.5, 0, diff[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,diff[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
# maximum abs Amplitude
plt.figure(figsize=(20, 10))
plt.title(" Max abs Amplitude difference")
diff = abs(np.array(app4_3) - np.array(app5_3))
plt.plot(diff)
plt.vlines((Left_edge-210)/0.5, 0, diff[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,diff[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, N_group, num=N_group+1)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %% [markdown]
# ## compensation factor

# %%
com = [] # compensation
com2 = []
for ele in app4_3:
    com.append((1/ele))

for ele in app5_3:
    com2.append(1/ele)

# %%
plt.figure(figsize=(20, 10))
plt.plot(com,c = 'y',label = "with no pile")
plt.plot(com2,c = 'b',label = "with a pile")
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, com2[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,com2[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, 81, num=82)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title(" Max abs Amplitude gradient")
x = np.linspace(210,250,81)
dx = (x[1]-x[0])
dydx1 = np.gradient(com, dx)
dydx2 = np.gradient(com2, dx)
plt.plot(abs(dydx1),c = 'y',label = "with no pile")
plt.plot(abs(dydx2),c = 'b',label = "with a pile")
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, abs(dydx2)[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,abs(dydx2)[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, 80, num=81)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title(" Max abs Amplitude gradient")
x = np.linspace(210,250,81)
split = 10
dx = (x[1]-x[0])/split
dydx11 = np.gradient(dydx1, dx)
dydx22 = np.gradient(dydx2, dx)
plt.plot(abs(dydx11),c = 'y',label = "with no pile")
plt.plot(abs(dydx22),c = 'b',label = "with a pile")
plt.legend()
plt.vlines((Left_edge-210)/0.5, 0, abs(dydx22)[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,abs(dydx22)[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, 80, num=81)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %% [markdown]
# # second time gradient

# %%
plt.figure(figsize=(20, 10))
plt.title(" Max abs Amplitude gradient")
x = np.linspace(210,250,81)
dd = abs(dydx11)
# dd = (dydx1)/dd.min()
plt.plot(dd,c = 'b',label = "with a pile")
plt.vlines((Left_edge-210)/0.5, 0, dd[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,dd[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, 80, num=81)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()


plt.figure(figsize=(20, 10))
plt.title(" Max abs Amplitude gradient")
x = np.linspace(210,250,81)
dd = abs(dydx22)
# dd = abs(dydx2)/dd.min()
plt.plot(dd,c = 'b',label = "with a pile")
plt.vlines((Left_edge-210)/0.5, 0, dd[int((Left_edge-210)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-210)/0.5, 0,dd[int((Right_edge-210)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0, 80, num=81)
label = ['210','210.5','211','211.5','212','212.5','213','213.5','214','214.5',
          '215','215.5','216','216.5','217','217.5','218','218.5','219','219.5',
          '220','220.5','221','221.5','222','222.5','223','223.5','224','224.5',
          '225','225.5','226','226.5','227','227.5','218','228.5','229','229.5',
          '230','230.5','231','231.5','232','232.5','233','233.5','234','234.5',
          '235','235.5','236','236.5','237','237.5','238','238.5','239','239.5',
          '240','240.5','241','241.5','242','242.5','243','243.5','244','244.5',
          '245','245.5','246','246.5','247','247.5','248','248.5','249','249.5',
          '250']
plt.xticks(x,label,rotation='vertical')
plt.show()

# %%
end = 219
start = 210

plt.figure(figsize=(20, 10))

index0 = int((start - 210 )/0.5)
print(index0)
index = int((end-210)/0.5)
print(index)

xx = np.linspace(start,end,int(index -index0)+1)
label = []
for ele in xx:
    label.append(str(ele))
dd = abs(dydx22)  
dd1 = dd[index0:index+1]
plt.plot(dd1)
plt.vlines((Left_edge-start)/0.5, 0, dd1[int((Left_edge-start)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-start)/0.5, 0,dd1[int((Right_edge-start)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0,int(index-index0),int(index-index0)+1)
print(label)
plt.xticks(x,label,rotation='vertical')
plt.show()


plt.figure(figsize=(20, 10))

index0 = int((start - 210 )/0.5)
print(index0)
index = int((end-210)/0.5)
print(index)

xx = np.linspace(start,end,int(index -index0)+1)
label = []
for ele in xx:
    label.append(str(ele))
dd = abs(np.gradient(com2, dx))
dd1 = dd[index0:index+1]
plt.plot(dd1)
plt.vlines((Left_edge-start)/0.5, 0, dd1[int((Left_edge-start)/0.5)],colors = "r", linestyles = "dashed")
plt.vlines((Right_edge-start)/0.5, 0,dd1[int((Right_edge-start)/0.5)],colors = "r", linestyles = "dashed")
x = np.linspace(0,int(index-index0),int(index-index0)+1)
print(label)
plt.xticks(x,label,rotation='vertical')
plt.show()
# Out:
# 0
# 18
# ['210.0', '210.5', '211.0', '211.5', '212.0', '212.5', '213.0', '213.5', '214.0', '214.5', '215.0', '215.5', '216.0', '216.5', '217.0', '217.5', '218.0', '218.5', '219.0']
# 0
# 18
# ['210.0', '210.5', '211.0', '211.5', '212.0', '212.5', '213.0', '213.5', '214.0', '214.5', '215.0', '215.5', '216.0', '216.5', '217.0', '217.5', '218.0', '218.5', '219.0']
